# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhishekSunil99/Data-science/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PANDAS
import pandas as pd
A=[10,20,30,40,50]
s=pd.Series(A)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
import pandas as pd
A=[10,20,30,40]
s=pd.Series(A,index=['A','B','C','D'])
print(s)
# Out:
# A    10
# B    20
# C    30
# D    40
# dtype: int64

# %%
import pandas as pd
data={'Name':'Abhiram','age':'9'}
s=pd.Series(data)
print(s)
# Out:
# Name    Abhiram
# age           9
# dtype: object

# %%
data=[10,20,30,40]
s=pd.Series(data)
print(s.loc[1])
# Out:
# 40

# %%
data=[10,20,30,40]
s=pd.Series(data)
print(s.loc[1])
print(s.iloc[-2])
# Out:
# 20
# 30
